# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
penguins = sns.load_dataset("penguins")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_theme()
sns.scatterplot(data=tips, x="total_bill",y="tip", hue="smoker")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill",y="tip", hue="day")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill",y="tip", hue="sex", style="time")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# line plots

# %%
flights=sns.load_dataset("flights")
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.lineplot(data=flights,x ="year",y="passengers",estimator="sum" )
#the default behaviour is to take the mean and plot but the estimator property talls it what to plot,eg max,sum etc
flights.groupby("year")["passengers"].mean().plot() #= the first line without estimator
# Out:
# <AxesSubplot:xlabel='year'>

# %%
sns.lineplot(data=flights,x ="year",y="passengers",hue="month" )
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
trips = sns.load_dataset("taxis",parse_dates=["pickup","dropoff"])
trips["hour"]= trips["pickup"].dt.hour

sns.lineplot(data=trips,x="hour",y="total",hue="payment")
# Out:
# <AxesSubplot:xlabel='hour', ylabel='total'>

# %%
sns.lineplot(data=trips,x="hour",y="total",hue="payment",style="color",ci=None)
# Out:
# <AxesSubplot:xlabel='hour', ylabel='total'>

# %%
sns.relplot(data=tips,x="total_bill",y="tip", kind="scatter")

# %%
sns.relplot(data=tips,x="total_bill",y="tip", kind="scatter" ,col="sex",hue="smoker")

# %%
sns.relplot(data=tips,x="total_bill",y="tip", kind="scatter" ,col="sex",hue="smoker",row="time")

# %%
#you do the same(above ) with kind="line"

# %% [markdown]
# PICKUP

# %%
sns.relplot(data=trips,x="hour",y="total",kind="line",col="pickup_borough",hue="payment")

# %% [markdown]
# HISTOGRAM

# %%
sns.histplot(data=tips, x="tip")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=tips, x="tip" ,hue="time")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=tips, x="tip",hue="smoker",multiple="stack")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=tips, x="tip",hue="smoker",multiple="dodge")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
sns.histplot(data=penguins,x="body_mass_g",bins=20,hue="species")
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=penguins,x="body_mass_g",bins=20,kde=True)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Count'>

# %% [markdown]
# KDE PLOTS

# %%
sns.kdeplot(data=penguins,x="body_mass_g",hue="species")
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Density'>

# %%
sns.kdeplot(data=penguins,x="body_mass_g",hue="species",bw_adjust=0.4)
#bandwidth adjust is for precision
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Density'>

# %%
sns.kdeplot(data=penguins,x="body_mass_g",hue="species",multiple="stack")
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Density'>

# %%
sns.kdeplot(data=penguins,x="body_mass_g",y="flipper_length_mm")
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.kdeplot(data=penguins,x="bill_length_mm",y="flipper_length_mm",hue="species")
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
sns.histplot(data=penguins,x="bill_length_mm",y="flipper_length_mm",hue="species")
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %% [markdown]
# RUGPLOT

# %%
sns.rugplot(data=tips,x="tip" ,height=0.4)
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
sns.rugplot(data=tips,y="tip" ,height=0.4)
# Out:
# <AxesSubplot:ylabel='tip'>

# %%
sns.kdeplot(data=tips,x="total_bill")
sns.rugplot(data=tips,x="total_bill",height=0.2)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# MOTHER DISPLOT METHOD

# %%
sns.displot(kind="hist",data=penguins,x="body_mass_g",height=3,col="species")
#this is a figure levvel method
