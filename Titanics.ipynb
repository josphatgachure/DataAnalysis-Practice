# %%
import pandas as pd
import matplotlib.pyplot as plt
titanic = pd.read_csv("train.csv")
titanic.head(5)
titanic["Pclass"].unique()
titanic["Pclass"].unique()

titanic['Age'].nlargest()

titanic.nsmallest(8,["Age"])

cols=["Name","Age","Sex"]
titanic.head(10)[cols]# it will give only these columns

titanic["Survived"].value_counts()# how many of each value present in that column
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
# Out:
#                                               PassengerId  Survived  Pclass  \
# Name
# Barkworth, Mr. Algernon Henry Wilson                  631         1       1
# Svensson, Mr. Johan                                   852         0       3
# Artagaveytia, Mr. Ramon                               494         0       1
# Goldschmidt, Mr. George B                              97         0       1
# Connors, Mr. Patrick                                  117         0       3
# ...                                                   ...       ...     ...
# Mannion, Miss. Margareth                              728         1       3
# Sage, Miss. Stella Anna                               793         0       3
# Goldenberg, Mrs. Samuel L (Edwiga Grabowska)          850         1       1
# Sage, Miss. Dorothy Edith "Dolly"                     864         0       3
# Johnston, Miss. Catherine Helen "Carrie"              889         0       3
#
# ...

# %%
titanic.nlargest(10,["Fare","Age"])
titanic.head(9).interpolate(method="linear",limit_direction="forward",axis =0)
titanic["Fare"].nlargest(10)
# Out:
# 258    512.3292
# 679    512.3292
# 737    512.3292
# 27     263.0000
# 88     263.0000
# 341    263.0000
# 438    263.0000
# 311    262.3750
# 742    262.3750
# 118    247.5208
# Name: Fare, dtype: float64

# %%
titanic.Pclass.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
titanic.head()
titanic.set_index("Fare")
# Out:
#          PassengerId  Survived  Pclass  \
# Fare
# 7.2500             1         0       3
# 71.2833            2         1       1
# 7.9250             3         1       3
# 53.1000            4         1       1
# 8.0500             5         0       3
# ...              ...       ...     ...
# 13.0000          887         0       2
# 30.0000          888         1       1
# 23.4500          889         0       3
# 30.0000          890         1       1
# 7.7500           891         0       3
#
#                                                       Name     Sex   Age  \
# Fare
# 7.2500                             Braund, Mr. Owen Harris    male  22.0
# 71.2833  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 7.9250                              Heikkinen, Miss. Laina  female  26.0
# 53.1000       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 8.0500                            Allen, Mr. William Henry    male  35.0
# ...

# %%
#titanic = pd.read_csv("train.csv" , index_col=3)
titanic.head(7)
#titanic[["Sex","Survived"]]
#titanic.sort_values("Age" ,ascending=False )#sorting
#titanic.sort_values(["Age" ,"Sex"],ascending=False ,inplace =True)

#titanic.sort_values(["Sex" ,"Age"],ascending=False ,inplace =True)#order matters
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# Moran, Mr. James                                              6         0
# McCarthy, Mr. Timothy J                                       7         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# ...

# %%
titanic.sort_values("Name",key=lambda col: col.str.lower())
titanic
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
titanic = pd.read_csv("train.csv", index_col=3)
titanic.sort_values("Age" )
titanic
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...
